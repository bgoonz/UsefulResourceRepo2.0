# %% [markdown]
# http://www.bogotobogo.com/python/scikit-learn/scikit_machine_learning_Data_Preprocessing-II-Datasets-Partitioning-Feature-scaling-Feature-Selection-Regularization.php

# %% [markdown]
# # L2 Regularization
# ![image.png](attachment:image.png)

# %% [markdown]
# # L1 Regularization
# ![image.png](attachment:image.png)

# %% [markdown]
# Can be a method of feature selection

# %% [markdown]
# This Notebook is a placeholder. I previously made notes on this subject in a physical notebook, i just wanted to save these pictures.
