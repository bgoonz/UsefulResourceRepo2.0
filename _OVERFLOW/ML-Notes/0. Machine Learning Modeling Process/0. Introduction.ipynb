# %% [markdown]
# # Machine Learning Process
#
# This will be covered in the following sections.
#
# https://machinelearningmastery.com/machine-learning-for-programmers/
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # Practice on Datasets
#
# https://machinelearningmastery.com/practice-machine-learning-with-small-in-memory-datasets-from-the-uci-machine-learning-repository/
#
#
# ### UCI Machine Learning Repository
#
# The UCI Machine learning repo is great to work on stuff in your desktop. You need to be able to practice the MachL process on different algorithms. How do we implement a good model?
#
# Must be able to perform the model development process fromm end to end. Once we can do that we can practice, afterr that we learn the bones of what makes these processes work. (C coding and mathematics and statistics)
#
#
# - Supervised Learning (classification and Regression)
# - Different sized datasets (small to large)
# - Different # of attributes
# - New types of problems
#
#
# Once we finish this section we will move on to creating a program of different MachL aglorithms to study and practice in implementation.
#
# Examples of traits to practice with:
#
#
# Binary Classification: Pima Indians Diabetes Data Set
# Multi-Class Classification: Iris Data Set
# Regression: Wine Quality Data Set
# Categorical Attributes: Breast Cancer Data Set
# Integer Attributes: Computer Hardware Data Set
# Classification Cost Function: German Credit Data
# Missing Data: Horse Colic Data Set
#
#
#
# ### Kaggle DataSets + Research Datasets
#
# https://machinelearningmastery.com/tour-of-real-world-machine-learning-problems/
#
#
# ### Datasets that Matter to You
#
# https://machinelearningmastery.com/work-on-machine-learning-problems-that-matter-to-you/

# %% [markdown]
# # Building a Machine Learning Portfolio
#
# https://machinelearningmastery.com/build-a-machine-learning-portfolio/
#
# - Each project has a clearly defined start and end point.
# - You will learn something from the project
# - Go for skills / try new things as often as possible
# - Practice your communication and delivery of results
#
# ## Properties of a Good Portfolio
#
# - Accessible (GitHub)
# - Small Tasks (10-20 Hours each)
# - Modest Goals (allows for project completion)
# - Understandable
#
#
# ## Project Ideas
#
# - Investigate a property of a machine Learning Tool
# - Investigate behavior of an algorithm
# - Investigate a dataset
# - Implement an algorithm
#
#
# # Marketing a Portfolio
