# %% [markdown]
# # A Few Useful Things to Know about Machine Learning
#
# https://homes.cs.washington.edu/~pedrod/papers/cacm12.pdf

# %% [markdown]
# ## 1. Introduction
# Machine Learning Systems automatically learn programs from data. The purpose of this article is to convey the folk knowledge necessary for some Machine Learning projects.
#
# Classifier - a system that inputes a vector and outputs a discrete class value
#
# Learner - inputs a training set of examples and outputs a classifier^^^

# %% [markdown]
# ## 2. Learning = Representation + Evaluation + Optimization
# When you have a problem that could be solved with machine learning the trick to navigating the wasteland of hundreds of potential machL algorithms is to remember that this space is a combination of three components.
#
# 1. Representation- how is the classifier represented in a formal language that a computer can handle? Choosing a representation determines what potential classifiers a learner can become. This set of potential classifiers is the hypothesis space of the learner.
#
# 2. Evaluation - Scoring/ objective function distinguishes good classifiers from bad ones. Does the algorithm have an internal objective function that matches the external goal which we wish to optimize?
#
# 3. Optimization - Need a method to search among classifiers for the highest scoring one.Optimization technique sets the efficiency of the learner

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 4. Data Alone is Not Enough
#
# If you are trying to model a lot of variables, the data needed grows exponentially. For learning a boolean function with 100 variables, you need $2^{100}$ examples. Every learner must have asumptions beyond the data its given in orger to generalize.
#
# Basically you are trying to model an unknnown function without perfect information. At some point guessing is more accurate then anything a learner could become.
#
# The functions we want to learn can have very basinc assumptions (smoothness, similar examples have limilar classes, limited dependencies, or limited complexity.) These simple assumptions allow machine learning to do WELL ENOUGH to be useful in certain situations. If you pick your battles and make the right assumptions you dont need god like amountss of data.
#
# Learners learn through induction, input examples create a large amount of output knowledge. (Think Marco Polo)  The more data we put in, the more we will get out.
#
# Choosing a representation for a learner is largely based off of what kind of knowledge are easily expressed by it.
#
# MACHINE LEARNINNG IS LIKE FARMING.

# %% [markdown]
# ## 5. Overfitting Has Many Faces.
#
# One Way of decomposing overfitting is bias vs variance. Bias is learners tendency to consistently learn the same wrong thing. Variance is learner learning random things regardless of the real signal. Similar to fishing for one fish with a net vs a harpoon. variance is issues with casting too wide a net, and bias is the issue of missing the target with your harpoon.
#
# Very rigid models have higher bias since they cant get on target with the true function. Flexible models have a high variance because they become too flexible and cast a wider prediction aas a result of flexing. In terms of optimization
#
# A more powerful (flexible?) learber i not necessarily better.  Strong false assumptions at times can perform better than weak true assumptions. mainly because more flexible learners require more data to avoid over fitting. The correct choice of algorithm depends on the amount of data and the assumptions you should make on what we can do to reduce variance and bias. Rule of thumb is produce more accurate results by lowering bias with flexible models and reduce variance by shoveling in a crap ton of data. Given a fixed amount of data, you must choose what amount of flexibility keeps bias low without overfitting.
#
# #### Ways to Combat Overfitting
#
# Cross fitting can help with hyperparameter tuning, but too much of this leads to overfitting as well.
#
# Another way is adding a regularization term to your evaluation function. this might penalize potential classifiers with more structure by adding certain constraints. Puts a limit on how much we can reduce variance and flex to data.
#
# Avoiding overfitting (variance) is a balancing act, dont go to far or else you risk underfitting (bias)
#
#
# #### Back to Overfitting
#
# Overfitting is not just caused by the presence of noise in our data. Overfitting can be similar to the problem of multiple testing in statistics. If we have enough trial runs of potential classifiers, one might get lucky but not actually be a good classifier on the real data. We have to make sure the performance of the classifier is significant and not just luck. Adjust the significance threshold based on the number of hypothesis being tested, tantamount to reducing the false discovery rate.

# %% [markdown]
# ## 6. Intuition Fails in High Dimensions
#
# Many algorithms that work in low dimensions are impossible in high dimensions. Generalizzing becomes exponentially harder as the number of features grows. Because a fixed number of training samples occupies a smaller and smaller fraction of the input space. Essentially finding a certain needle in a hay stack vs finding a certain needle in New York. Each training example gives us a glimpse of our surroundings, but finding something in New York requires many many observations.
#
# The similarity assumption breaks down in high dimension. A nearest neighbor in high d might have certain features that signal a true output, unfortunately alll of the other features might produce enough noise output that a correct classification might be drowned out.
#
# As the dimensionalty increases so do the number of nearest neighbors since space expands. think 3 feet vs 3 feet$^{2}$ one has a significantly higher spatial containment. THus in high enough D every example might seem similar, so how do we classify?

# %% [markdown]
# ## 10. Learn Many Models, Not Just One
#
# "But then researchers noticed that, if instead
# of selecting the best variation found, we combine many variations,
# the results are better—often much better—and at
# little extra effort for the user.
# Creating such model ensembles is now standard [1]. In the
# simplest technique, called bagging, we simply generate random
# variations of the training set by resampling, learn a
# classifier on each, and combine the results by voting. This
# works because it greatly reduces variance while only slightly
# increasing bias. In boosting, training examples have weights,
# and these are varied so that each new classifier focuses on
# the examples the previous ones tended to get wrong. In
# stacking, the outputs of individual classifiers become the inputs
# of a “higher-level” learner that figures out how best to
# combine them."

# %% [markdown]
# # Neural Network Topology
# http://colah.github.io/posts/2014-03-NN-Manifolds-Topology/

# %% [markdown]
# # Understanding MachL Algorithms
# https://www.cs.huji.ac.il/~shais/UnderstandingMachineLearning/understanding-machine-learning-theory-algorithms.pdf

# %% [markdown]
# Learning requires an ability to generalize.
# Inductive reasoning - learn from examples and make generalizations about new instances
#
#
# Inductive reasoning can lead to false conclusions in superstition. ie patterns in data that dont actually lead to a desired outcome prediction. In this case our data and chance leads us to a suboptimal learning.
#
#
# The problem: believing in an association with good outcome causes you to do the same action again and create a stronger association.
#
# Machine Learning algorithms are built with the intention of avoiding superstitious and chance beliefs. In this way superstition can be seen as a kind of overfitting to the chance patterns seen in the data.

# %% [markdown]
# #### 1.2 When do we need Machine Learning?
#
# Prior Knowledge that biases the learning mechanism. this is called inductive bias. An agent will explain certain stimulis irrationally or differently while a bias is present.
#
# Prior knowledge cannot be avoided, Free Lunch Theorem
# The stronger the prior knowledge/ prior assumptions the easier it is to learn from further examples. Also, the less flexible the learning is ( bound to these assumptions.)
#
# To the machine agent we develop prior assumptions to reduce the number of possible number of classifiers and focus the development of a learner. Thoughtless assumptions can constrain a learner, by being counterproductive and making counterexamples harder to learn from.
#
# ##### Supervised vs Unsupervised
#
# Supervised - the learner processes input examples and comes up with a rule that comresses the data.
# (Clusters in KNN, Hyperplanes in lin reg, dec rules in dec trees, etc.)
#
# ##### Active vs Passive Learners
#
# Active learners interact with the enviornment at training time (by posing queries) Passive just observes data without influencing or directing it.
#
# ##### Helpfulness of the Teacher
#
# The assumption is that the enviornment plays the role of the teacher through random processes. (key assumption of statistical learning) Learninng can also occur at the whim of an adversarial teacher.
#
# #### Machine Learning
#
# Traditional statistics is useful for the testing of certain posed hypothesis. Much of the value of Machine Learning lies in its ability to create fruitful hypothesis and potential interrelations between data.
#
# Another difference is that the learner does not make assumptions about the distribution of the data

# %% [markdown]
# ## 2 Foundations
#  ### 2.1 A Gentle Start
#
#  #### A Standard Statistical Learning Framework
#
#  Input Data:
#
#  Domain Set - Set X the set of all potential samples based on certain features.
#
#  Label Set - the poteential classifiers
#
#  Training data - S =  {{x,y},{x,y},...}
#
#  The Output of a Learner:
#
#  The learner outputs a prediction rule (i.e. hypothesis) which can be used to predict new decision data.
#
#  Data Generation Model:
#
#  We take a sample from the domain set X with distribution D, ans label them correctly. Need a correct labeling function, which the learner will try to predict/ model.
#
#  Training Data = S
#  Possible Data = X
#  Distribution = D
#  Learner Algorithm = A
#
#
#  Measure of Success: the probability of classifying wrongly on a random instance x from X
#
# ### 2.2 Risk Minimization
#
# Goal of the algorithm is to fing the decision rule that minimizies error with respectt to the unknown distribution D of the true pop X and the unknown true classifying function f.
#
# Measuring training accuracy is a tool to find  empirical risk/error.
#
# #### Empirical Risk Minimization with Inductive Bias
#
#
# This book is too contrived, moving on to the next resource.

# %% [markdown]
# # Learn Data Science
#
# http://learnds.com/

# %% [markdown]
# ## Linear Regression Overview
#
# The purpose of model  building is to predict the interrelationships between real world variables.
#
# Model predicts a response to several variables (covariates)
#
# Linear Model - we assume the outcome has a linear relationship with the independent variables.
#
#
# ### Assumptions of Linear Regression
#
# http://pareonline.net/getvn.asp?n=2&v=8
#
#     1. Variables are normally distributed. (Violators: skewed data, outliers. Causes poor linear best fit.)
#
#
# Dealing with data issues. One possible solution is to remove outliers. (This should increase your accuracy) Another is transformations (sq root, log,  inverse) which improves normality but complicaates interpretation.  Solution breaks down to make your data more normal...
#
#
#     2. Linear relationship between independent and dependent variables.
#
# Solution: run regression analysis with curvilinear componnents ($x^{2}$ or $x^{3}$)
#
#
#     3. Data is collected accurately
#
#
#
#     4. Homeskadicity - variance of errors is the same (variance doesnt change with covariates)
#
#
# ### Justifications for Assumptions
# http://people.duke.edu/~rnau/regintro.htm
#
# linear relations are simple, are often reasonably accurate.
#
# We must realize that with multivariate linear regression we assume that the effect of independent variables are solely additive, ie change in one variable does not change the effect of another variable.
#
# Correlation - the strength of the linear relationship between two independent variables. If one variable is significantly correlated with another, its effects can be accounted for in the linear combination of only one of the two. IE it is an unnecessary term that might effect accuracy. (is a scatter plot between the two linear or cloudy?) perfect correlation is ${+}/{-}$ 1.0.
#
#
# When we have fitted a linear model we can compute the variance of its errors, and compare this to the variance of the dependent variable
#
#
# ### Problems With Linear Regression
#
# http://www.dataschool.io/applying-and-interpreting-linear-regression/
#
# #### Non-Linear Relationships
# - plot residuals versus y values or x values
# - use nonlinear transforms on covariates
# - seek combinations of input to fix this
#
# #### Outliers
# - Remove from data set
#
#
# #### High Leverage Points
# - ?????
#
#
# ####  Collinearity
# - correlation between predictors
# - look out for multicollinearity with VIF
# - combine correlated variables into a single predictor
#
# Fixed by making a correlation matric and then finding eigenvalues that are close to zero. See Linear Regression code.
#
#
# ### Assumption of Normal Distribution
# https://www.researchgate.net/post/Is_linear_regression_valid_when_the_outcome_dependant_variable_not_normally_distributed
#  - assume a normal distribution of errors not outcome or covariates. Errors have a mean of zero and some variance
#
# ### The Meaning of $R^{2}$
# http://people.duke.edu/~rnau/rsquared.htm
#
# R- squared is the fraction by which the variance of the errors is lass than the variance of the dependent variable. (percent of the variance that is explained by the linear relation)

# %% [markdown]
# ## L1 vs L2 Regularization
# The regularized term lies on one of the two curves.
#
# ![image.png](attachment:image.png)
#
# ### L1 Regularization
# L1 regularization is based off of absolute difference. The regularization is in linear proportion to the absolute distance.
#
# "Contrarily, L1 regularization forces non-essential entries of theta all the way to zero."
#
#
# ### L2 Regularization
# Based off of squared distance. Pulled towards zero in proportion to the square distance.
#
# "The result is that L2 regularization drives many of your parameters down, but will not necessarily eradicate them, since the penalty all but disappears near zero."

# %% [markdown]
# ## Elastic Net vs LASSO vs Ridge
#
# https://stats.stackexchange.com/questions/93181/ridge-lasso-and-elastic-net
#
# https://stats.stackexchange.com/questions/866/when-should-i-use-lasso-vs-ridge
#
#
#
# ![image.png](attachment:image.png)
#
#
#
# ### Ridge (shrink the coeffs)
# Uses L2 regularization - vulnerable to outliers, limits the size of the coefficient vector, but does not create a sparse coefficient vector. computationally less expensive.
#
# ### LASSO  (sparse coeffs)
#
# uses L1 regularization more robust, butless computationally efficient. Designed to create sparse vector ~> feature engineering is built in. one does not know which variables are put in.
#
# Vulnerable to correlated data!!! if this is present, use elastic net.
#
# ### Elastic Net (shrink and sparse)
#
# Compromise between the two uses both L1 and L2. Use when collinearity is expected.
